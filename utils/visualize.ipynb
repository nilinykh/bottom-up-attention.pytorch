# %%
# set up Python environment: numpy for numerical routines, and matplotlib for plotting
import numpy as np
import matplotlib.pyplot as plt
import pylab
from skimage import transform
# display plots in this notebook
# %matplotlib inline

import os

# set display defaults
plt.rcParams['figure.figsize'] = (12, 9)        # small images
plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels
plt.rcParams['image.cmap'] = 'gray'  # use grayscale output rather than a (potentially misleading) color heatmap

# %%
data_path = '../evaluation'

# Load classes
classes = ['__background__']
with open(os.path.join(data_path, 'objects_vocab.txt')) as f:
    for object in f.readlines():
        classes.append(object.split(',')[0].lower().strip())

# Load attributes
attributes = ['__no_attribute__']
with open(os.path.join(data_path, 'attributes_vocab.txt')) as f:
    for att in f.readlines():
        attributes.append(att.split(',')[0].lower().strip())

# %%
len(attributes)
# Out:
# 401

# %%
import argparse
import os
import sys
import torch
import tqdm
import cv2
import numpy as np
sys.path.append('../detectron2')
sys.path.append('../')

import detectron2.utils.comm as comm
from detectron2.checkpoint import DetectionCheckpointer
from detectron2.data import build_detection_test_loader, build_detection_train_loader
from detectron2.config import get_cfg
from detectron2.engine import DefaultTrainer, default_setup, launch
from detectron2.evaluation import COCOEvaluator, verify_results

from utils import mkdir, save_features
from extract_utils import get_image_blob
from models.bua import add_bottom_up_attention_config
from models.bua.layers.nms import nms

# %%
config_file = '../configs/bua-caffe/extract-bua-caffe-r152.yaml'

cfg = get_cfg()
add_bottom_up_attention_config(cfg, True)
cfg.merge_from_file(config_file)
cfg.freeze()
# Out:
# Config '../configs/bua-caffe/extract-bua-caffe-r152.yaml' has no VERSION. Assuming it to be compatible with latest v2.

# %%
MIN_BOXES = 1
MAX_BOXES = 2
CONF_THRESH = 0.4

model = DefaultTrainer.build_model(cfg)
DetectionCheckpointer(model, save_dir=cfg.OUTPUT_DIR).resume_or_load(
    '../bua-caffe-frcn-r152_with_attributes.pth', resume=True
)
model.eval()
# Out:
# GeneralizedBUARCNN(
#   (backbone): ResNet(
#     (stem): BUABasicStemv2(
#       (norm): FrozenBatchNorm2d(num_features=3, eps=2e-05)
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=2e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlockv2(
#         (shortcut): Conv2dv2(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1): Conv2dv2(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=64, eps=2e-05)
#       )
#       (1): BottleneckBlockv2(
#         (conv1): Conv2dv2(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=256, eps=2e-05)
#       )
#       (2): BottleneckBlockv2(
#         (conv1): Conv2dv2(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=256, eps=2e-05)
#       )
#     )
#     (res3): Sequential(
#       (0): BottleneckBlockv2(
#         (shortcut): Conv2dv2(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (conv1): Conv2dv2(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=256, eps=2e-05)
#       )
#       (1): BottleneckBlockv2(
#         (conv1): Conv2dv2(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=512, eps=2e-05)
#       )
#       (2): BottleneckBlockv2(
#         (conv1): Conv2dv2(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=512, eps=2e-05)
#       )
#       (3): BottleneckBlockv2(
#         (conv1): Conv2dv2(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=512, eps=2e-05)
#       )
#       (4): BottleneckBlockv2(
#         (conv1): Conv2dv2(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=512, eps=2e-05)
#       )
#       (5): BottleneckBlockv2(
#         (conv1): Conv2dv2(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=512, eps=2e-05)
#       )
#       (6): BottleneckBlockv2(
#         (conv1): Conv2dv2(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=512, eps=2e-05)
#       )
#       (7): BottleneckBlockv2(
#         (conv1): Conv2dv2(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (conv3): Conv2dv2(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=2e-05)
#         )
#         (norm): FrozenBatchNorm2d(num_features=512, eps=2e-05)
#       )
#     )
#     (res4): Sequential(
#       (0): BottleneckBlockv2(
#         (shortcut): Conv2dv2(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (conv1): Conv2dv2(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(512, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (10): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (11): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (12): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (13): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (14): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (15): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (16): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (17): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (18): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (19): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (20): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (21): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (22): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (23): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (24): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (25): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (26): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (27): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (28): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (29): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (30): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (31): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (32): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (33): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (34): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (35): BottleneckBlockv2(
#         (conv1): Conv2dv2(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (proposal_generator): BUARPN(
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#     (rpn_head): StandardBUARPNHead(
#       (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(512, 48, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): BUACaffeRes5ROIHeads(
#     (pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): RoIPool(output_size=(14, 14), spatial_scale=0.0625)
#       )
#     )
#     (res5): Sequential(
#       (0): BottleneckBlockv2(
#         (shortcut): Conv2dv2(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (conv1): Conv2dv2(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(512, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(512, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(1024, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BottleneckBlockv2(
#         (conv1): Conv2dv2(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(512, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(512, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(2048, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BottleneckBlockv2(
#         (conv1): Conv2dv2(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2dv2(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(512, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2dv2(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(512, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (norm): BatchNorm2d(2048, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (res5_bn): BatchNorm2d(2048, eps=2e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (box_predictor): BUACaffeFastRCNNOutputLayers(
#       (cls_score): Linear(in_features=2048, out_features=1601, bias=True)
#       (bbox_pred): Linear(in_features=2048, out_features=6404, bias=True)
#       (cls_embed): Embedding(1601, 256)
#       (attr_linear1): Linear(in_features=2304, out_features=512, bias=True)
#       (attr_linear2): Linear(in_features=512, out_features=400, bias=True)
#     )
#   )
# )

# %%
im_file = '/home/nikolai/imgs/2346802.jpg'

im = cv2.imread(im_file)
dataset_dict = get_image_blob(im, [0, 0, 0])

with torch.set_grad_enabled(False):
    boxes, scores, features_pooled, attr_scores = model([dataset_dict])

dets = boxes[0].tensor.cpu() / dataset_dict['im_scale']
scores = scores[0].cpu()
feats = features_pooled[0].cpu()
attr_scores = attr_scores[0].cpu()

max_conf = torch.zeros((scores.shape[0])).to(scores.device)
for cls_ind in range(1, scores.shape[1]):
        cls_scores = scores[:, cls_ind]
        keep = nms(dets, cls_scores, 0.3)
        max_conf[keep] = torch.where(cls_scores[keep] > max_conf[keep],
                                    cls_scores[keep],
                                    max_conf[keep])
            
keep_boxes = torch.nonzero(max_conf >= CONF_THRESH).flatten()
if len(keep_boxes) < MIN_BOXES:
    keep_boxes = torch.argsort(max_conf, descending=True)[:MIN_BOXES]
elif len(keep_boxes) > MAX_BOXES:
    keep_boxes = torch.argsort(max_conf, descending=True)[:MAX_BOXES]

im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(im)

boxes = dets[keep_boxes].numpy()
objects = np.argmax(scores[keep_boxes].numpy()[:,1:], axis=1)
attr_thresh = 0.1
attr = np.argmax(attr_scores[keep_boxes].numpy()[:,1:], axis=1)
attr_conf = np.max(attr_scores[keep_boxes].numpy()[:,1:], axis=1)


for i in range(len(keep_boxes)):
    bbox = boxes[i]
    if bbox[0] == 0:
        bbox[0] = 1
    if bbox[1] == 0:
        bbox[1] = 1
    cls = classes[objects[i]+1]
    if attr_conf[i] > attr_thresh:
        cls = attributes[attr[i]+1] + " " + cls
    plt.gca().add_patch(
        plt.Rectangle((bbox[0], bbox[1]),
                      bbox[2] - bbox[0],
                      bbox[3] - bbox[1], fill=False,
                      edgecolor='red', linewidth=2, alpha=0.5)
            )
    plt.gca().text(bbox[0], bbox[1] - 2,
                '%s' % (cls),
                bbox=dict(facecolor='blue', alpha=0.5),
                fontsize=10, color='white')
print('boxes={}'.format(len(keep_boxes)))
print('features', feats, feats.shape)
#print(attr_scores,  attr_scores.shape)
# Out:
# boxes=2
# features tensor([[0.0000, 0.4394, 2.4174,  ..., 0.0000, 0.0000, 0.2529],
#         [0.0000, 0.3262, 0.8726,  ..., 0.0000, 0.0000, 0.1122],
#         [0.0000, 0.6819, 0.0000,  ..., 0.0000, 0.0000, 0.0173],
#         ...,
#         [0.0000, 0.2784, 1.3530,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0155, 5.6766,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.2275, 8.1354,  ..., 0.0000, 0.0340, 0.6642]]) torch.Size([165, 2048])
